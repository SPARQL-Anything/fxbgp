# %%
import pandas as pd

df = pd.read_csv('/Users/lgu/Library/CloudStorage/GoogleDrive-luigi.asprino@gmail.com/My Drive/Lavoro/Projects-GDrive/FBDA/Research/stream-performance/performance-analysis/stream-performance-csv/time.tsv', sep='\t')
